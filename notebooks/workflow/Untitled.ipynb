# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.DataFrame(range(4)).plot()

# %%
fig, axes = plt.subplots(10, figsize=(15, 5))

# %%
fig = plt.figure()
for i in range(3):
    ax = fig.add_subplot(1,1,)
    ax.plot(pd.DataFrame(range(4)))
    print(ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-2a5a245f689d> in <module>()
#       1 fig = plt.figure()
#       2 for i in range(3):
# ----> 3     ax = fig.add_subplot(1,1,i)
#       4     ax.plot(pd.DataFrame(range(4)))
#       5     print(ax)
#
# /home/dafne/anaconda2/envs/ucl2/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /home/dafne/anaconda2/envs/ucl2/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      62                     raise ValueError(
#      63                         "num must be 1 <= num <= {maxn}, not {num}".format(
# ...
